# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('placement.csv')
df.sample()
# Out:
#      cgpa  package
# 125  7.33     3.16

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.show()

# %%
X = df.iloc[:, [0]]
y = df.iloc[:, [1]]
X, y
# Out:
# (     cgpa
#  0    6.89
#  1    5.12
#  2    7.82
#  3    7.42
#  4    6.94
#  ..    ...
#  195  6.93
#  196  5.89
#  197  7.21
#  198  7.63
#  199  6.22
#
#  [200 rows x 1 columns],
#       package
#  0       3.26
#  1       1.98
#  2       3.25
#  3       3.67
#  4       3.57
#  ..       ...
#  195     2.46
#  196     2.57
#  197     3.24
#  198     3.96
#  199     2.33
#
#  [200 rows x 1 columns])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test, y_test
# Out:
# (     cgpa
#  112  8.58
#  29   7.15
#  182  5.88
#  199  6.22
#  193  4.57
#  85   4.79
#  10   5.32
#  54   6.86
#  115  8.35
#  35   6.87
#  12   8.94
#  92   7.90
#  13   6.93
#  126  5.91
#  174  7.32
#  2    7.82
#  44   5.09
#  3    7.42
#  113  6.94
#  14   7.73
#  23   6.19
#  25   7.28
#  6    6.73
#  134  7.20
#  165  8.21
#  173  6.75
#  45   7.87
#  65   7.60
#  48   8.63
#  122  5.12
#  178  8.15
#  64   7.36
#  9    8.31
#  57   6.60
#  78   6.59
#  71   7.47
#  128  7.93
#  176  6.29
#  131  6.37
#  53   6.47,
#       package
#  112     4.10
#  29      3.49
#  182     2.08
#  199     2.33
#  193     1.94
#  85      1.48
#  10      1.86
#  54      3.09
#  115     4.21
#  35      2.87
#  12      3.65
#  92      4.00
#  13      2.89
#  126     2.60
#  174     2.99
#  2       3.25
#  44      1.86
#  3       3.67
#  113     2.37
#  14      3.42
#  23      2.48
#  25      3.65
#  6       2.60
#  134     2.83
#  165     4.08
#  173     2.56
#  45      3.58
#  65      3.81
# ...

# %%
pred = lr.predict(X_test.iloc[[0]])
pred
# Out:
# array([[3.89111601]])

# %%
lr.predict(X_test.iloc[[1]])
# Out:
# array([[3.09324469]])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.show()

'''Using X_train vs X_test:
    X_train is the data used to train the model, so plotting the regression line using X_train shows how well the model fits the training data.
    X_test is the data used to evaluate the model's performance on unseen data. If X_test is small or not representative, the regression line might not look smooth or meaningful.
'''

plt.scatter(df['cgpa'], df['package'])
plt.plot(X_test, lr.predict(X_test), color = 'red')
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.show()

# %% [markdown]
# ## Calculate the slope line

# %%
m = lr.coef_
m
# Out:
# array([[0.55795197]])

# %%
b = lr.intercept_
b
# Out:
# array([-0.89611192])

# %%
# y = mx + b
#x is the first val in X_test which is CGPA 8.58
m*(X_test.iloc[0,0])+ b
# Out:
# array([[3.89111601]])
