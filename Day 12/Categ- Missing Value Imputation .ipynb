# %% [markdown]
# # Missing value imputation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv', usecols = ['GarageQual', 'FireplaceQu', 'SalePrice'])

# %%
df.sample(10)
# Out:
#      FireplaceQu GarageQual  SalePrice
# 89           NaN        NaN     123600
# 1238         NaN         TA     142500
# 675           TA         TA     148500
# 547          NaN         TA     129500
# 242          NaN         Fa      79000
# 467           Gd         TA     146500
# 1244          Gd         TA     230000
# 996          NaN         TA     136500
# 403           TA         TA     258000
# 738          NaN        NaN     179000

# %% [markdown]
# ### Checking for missing (NULL) values

# %%
(df.isnull().mean()*100).round(2)
# Out:
# FireplaceQu    47.26
# GarageQual      5.55
# SalePrice       0.00
# dtype: float64

# %% [markdown]
# ### Plot bar for Garage

# %%
df['GarageQual'].value_counts().sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
plt.show()

# %% [markdown]
# ### Replacing missing values with "MISSING"

# %%
df['GarageQual'].fillna('MISSING', inplace = True)

# %% [markdown]
# ### Category Missing Values

# %%
df['GarageQual'].value_counts(ascending = False).plot.bar()
plt.ylabel('Number of houses')
plt.show()
